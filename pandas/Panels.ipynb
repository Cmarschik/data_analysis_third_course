# %%
import pandas as pd
from pandas_datareader import data

# %%
companies = ["MSFT", "GOOG", "AAPL", "AABA", "AMZN"]# can use a list of companies to return a panal (AABA is what yahoo was-ish)

p = data.DataReader(name = companies,
                data_source = "yahoo",
                start = "2010-01-01",
                end = "2019-12-31")
p
# Out:
# Attributes       High                                                    \
# Symbols          AABA        AAPL         AMZN         GOOG        MSFT
# Date
# 2010-01-04  17.200001   30.642857   136.610001   312.721039   31.100000
# 2010-01-05  17.230000   30.798571   135.479996   311.891449   31.100000
# 2010-01-06  17.299999   30.747143   134.729996   310.907837   31.080000
# 2010-01-07  16.900000   30.285715   132.320007   303.029083   30.700001
# 2010-01-08  16.760000   30.285715   133.679993   299.675903   30.879999
# 2010-01-11  16.830000   30.428572   132.800003   300.276978   30.760000
# 2010-01-12  16.860001   29.967142   129.820007   297.147339   30.400000
# 2010-01-13  16.980000   30.132856   129.710007   292.288940   30.520000
# 2010-01-14  17.230000   30.065714   130.380005   295.180145   31.100000
# 2010-01-15  17.250000   30.228571   129.649994   294.862213   31.240000
# 2010-01-19  16.959999   30.741428   128.000000   293.302338   31.240000
# ...

# %% [markdown]
# # The Axes of a Panel Object

# %%
# Panel is depricated, all is returned as a DF

# %%
companies = ["MSFT", "GOOG", "AAPL", "AABA", "AMZN"]# can use a list of companies to return a panal (AABA is what yahoo was-ish)

p = data.DataReader(name = companies,
                data_source = "yahoo",
                start = "2010-01-01",
                end = "2019-12-31")
p.head(3)
# Out:
# Attributes       High                                                  Low  \
# Symbols          AABA       AAPL        AMZN        GOOG   MSFT       AABA
# Date
# 2010-01-04  17.200001  30.642857  136.610001  312.721039  31.10  16.879999
# 2010-01-05  17.230000  30.798571  135.479996  311.891449  31.10  17.000000
# 2010-01-06  17.299999  30.747143  134.729996  310.907837  31.08  17.070000
#
# Attributes                                                ...      Volume  \
# Symbols          AAPL        AMZN        GOOG       MSFT  ...        AABA
# Date                                                      ...
# 2010-01-04  30.340000  133.139999  310.103088  30.590000  ...  16587400.0
# 2010-01-05  30.464285  131.809998  308.761810  30.639999  ...  11718100.0
# 2010-01-06  30.107143  131.649994  301.220856  30.520000  ...  16422000.0
#
# Attributes                                                Adj Close  \
# Symbols            AAPL       AMZN       GOOG        MSFT      AABA
# Date
# ...

# %%
p.items
# Out:
# <bound method DataFrame.iteritems of Attributes       High                                                    \
# Symbols          AABA        AAPL         AMZN         GOOG        MSFT
# Date
# 2010-01-04  17.200001   30.642857   136.610001   312.721039   31.100000
# 2010-01-05  17.230000   30.798571   135.479996   311.891449   31.100000
# 2010-01-06  17.299999   30.747143   134.729996   310.907837   31.080000
# 2010-01-07  16.900000   30.285715   132.320007   303.029083   30.700001
# 2010-01-08  16.760000   30.285715   133.679993   299.675903   30.879999
# 2010-01-11  16.830000   30.428572   132.800003   300.276978   30.760000
# 2010-01-12  16.860001   29.967142   129.820007   297.147339   30.400000
# 2010-01-13  16.980000   30.132856   129.710007   292.288940   30.520000
# 2010-01-14  17.230000   30.065714   130.380005   295.180145   31.100000
# 2010-01-15  17.250000   30.228571   129.649994   294.862213   31.240000
# ...
